# %%
# import pandas
import pandas as pd

# %%
# read well log CSV data
## processed from las_converter.py
well_df = pd.read_csv("results/well.csv")
well_desc = pd.read_csv("results/description.csv")

# %%
# display well description
well_desc
# Out:
#            name                           description
# 0         vers.  CWLS LOG ASCII STANDARD--VERSION 2.0
# 1         wrap.               ONE LINE PER DEPTH STEP
# 2       strt.ft                           START DEPTH
# 3       stop.ft                            STOP DEPTH
# 4       step.ft                                  STEP
# 5         null.                            NULL VALUE
# 6         comp.                               COMPANY
# 7         well.                             WELL NAME
# 8          uwi.                              WELL UWI
# 9          api.                              WELL API
# 10         loc.                         WELL LOCATION
# 11        date.                             WELL DATE
# 12         fld.                          Project NAME
# 13  m__depth.ft                              M__DEPTH
# 14           sp                                    SP
# 15           gr                                    GR
# ...

# %%
# let's see several information about this well data
well_df.head()
# Out:
#    m__depth.ft  sp       gr  cali  bitsize  msfl  ll8  ilm  ild  lld  lls  \
# 0        104.0 NaN  28.4006   NaN     17.5   NaN  NaN  NaN  NaN  NaN  NaN
# 1        104.5 NaN      NaN   NaN     17.5   NaN  NaN  NaN  NaN  NaN  NaN
# 2        105.0 NaN      NaN   NaN     17.5   NaN  NaN  NaN  NaN  NaN  NaN
# 3        105.5 NaN      NaN   NaN     17.5   NaN  NaN  NaN  NaN  NaN  NaN
# 4        106.0 NaN      NaN   NaN     17.5   NaN  NaN  NaN  NaN  NaN  NaN
#
#    rhob  nphi       dt  mudwgt
# 0   NaN   NaN  99.4842     9.2
# 1   NaN   NaN  99.5375     9.2
# 2   NaN   NaN  96.0702     9.2
# 3   NaN   NaN  95.4594     9.2
# 4   NaN   NaN  96.6074     9.2

# %%
well_df.tail()
# Out:
#        m__depth.ft  sp  gr  cali  bitsize  msfl  ll8  ilm  ild  lld  lls  \
# 40458      20333.0 NaN NaN   NaN      NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 40459      20333.5 NaN NaN   NaN      NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 40460      20334.0 NaN NaN   NaN      NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 40461      20334.5 NaN NaN   NaN      NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 40462      20335.0 NaN NaN   NaN      NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
#        rhob  nphi  dt  mudwgt
# 40458   NaN   NaN NaN    15.5
# 40459   NaN   NaN NaN    15.5
# 40460   NaN   NaN NaN    15.5
# 40461   NaN   NaN NaN    15.5
# 40462   NaN   NaN NaN    15.5

# %%
well_df.describe()
# Out:
#         m__depth.ft            sp            gr          cali      bitsize  \
# count  40463.000000  40050.000000  40272.000000  31384.000000  40439.00000
# mean   10219.500000     -6.821283     61.071525     13.886682     12.27960
# std     5840.403154      7.373643     23.003296      4.809959      4.77249
# min      104.000000    -65.692160      2.609000      4.936400      6.25000
# 25%     5161.750000     -9.217485     42.512725      9.702575      6.25000
# 50%    10219.500000     -4.548295     60.358500     14.212100     12.25000
# 75%    15277.250000     -1.852027     76.831225     18.069825     17.50000
# max    20335.000000      6.888950    192.827390     21.761600     17.50000
#
#                msfl           ll8           ilm           ild          lld  \
# count  16119.000000  16157.000000  32165.000000  32155.000000  8149.000000
# mean       8.254331     92.890528     14.598919     17.923826    11.161442
# ...

# %%
# make a plot of logging
## gamma ray along with the depth
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5, 15))

# plt.plot(well_df["gr"], well_df["m__depth.ft"])
plt.scatter(well_df["gr"], well_df["m__depth.ft"], color="black", s=.5)

plt.title("GR")
plt.xlabel("gamma ray")
plt.ylabel("depth (ft)")
plt.ylim(ymax=0, ymin=well_df["m__depth.ft"].max())
plt.show()
