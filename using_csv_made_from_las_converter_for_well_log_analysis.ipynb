# %%
# import pandas
import pandas as pd

# %%
# read well log CSV data
## processed from las_converter.py
well_df = pd.read_csv("results/well.csv")
well_desc = pd.read_csv("results/description.csv")

# %%
# display well description
well_desc
# Out:
#            name                           description
# 0         vers.  CWLS LOG ASCII STANDARD--VERSION 2.0
# 1         wrap.               ONE LINE PER DEPTH STEP
# 2       strt.ft                           START DEPTH
# 3       stop.ft                            STOP DEPTH
# 4       step.ft                                  STEP
# 5         null.                            NULL VALUE
# 6         comp.                               COMPANY
# 7         well.                             WELL NAME
# 8          uwi.                              WELL UWI
# 9          api.                              WELL API
# 10         loc.                         WELL LOCATION
# 11        date.                             WELL DATE
# 12         fld.                          Project NAME
# 13  m__depth.ft                              M__DEPTH
# 14           sp                                    SP
# 15           gr                                    GR
# 16         cali                                  CALI
# 17      bitsize                               BitSize
# 18         msfl                                  MSFL
# 19          lld                                   LLD
# 20          lls                                   LLS
# 21         rhob                                  RHOB
# 22         nphi                                  NPHI
# 23           dt                                    DT
# 24       mudwgt                                MudWgt

# %%
# let's see several information about this well data
well_df.head()
# Out:
#    m__depth.ft  sp  gr  cali  bitsize  msfl  lld  lls  rhob  nphi  dt  mudwgt
# 0         98.0 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN     NaN
# 1         98.5 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN     NaN
# 2         99.0 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN     NaN
# 3         99.5 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN     NaN
# 4        100.0 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN     8.9

# %%
well_df.tail()
# Out:
#       m__depth.ft  sp  gr  cali  bitsize  msfl  lld  lls  rhob  nphi  dt  \
# 8520       4358.0 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN
# 8521       4358.5 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN
# 8522       4359.0 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN
# 8523       4359.5 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN
# 8524       4360.0 NaN NaN   NaN      NaN   NaN  NaN  NaN   NaN   NaN NaN
#
#       mudwgt
# 8520    10.3
# 8521    10.3
# 8522    10.3
# 8523    10.3
# 8524    10.3

# %%
well_df.describe()
# Out:
#        m__depth.ft           sp           gr         cali      bitsize  \
# count  8525.000000  8368.000000  8417.000000  8461.000000  8487.000000
# mean   2229.000000   -12.860387    83.781443    12.244125    10.443708
# std    1230.549928    13.889969    16.499917     2.932885     1.873851
# min      98.000000   -86.666860    18.723600     8.018100     8.500000
# 25%    1163.500000   -15.039402    76.034500     8.804000     8.500000
# 50%    2229.000000    -9.566770    83.253700    12.722900    12.250000
# 75%    3294.500000    -4.932437    92.818900    14.962000    12.250000
# max    4360.000000     4.277320   199.927400    17.872500    12.250000
#
#               msfl          lld          lls         rhob         nphi  \
# count  8353.000000  8346.000000  8355.000000  8485.000000  8445.000000
# mean      6.683239    15.175094    14.305722     2.328823    40.078543
# std      12.512910    18.689141    17.456410     0.183474    11.512789
# min       0.315600     0.217100     0.215400     1.914600    11.113600
# 25%       2.493700     8.214450     8.425000     2.193900    29.391000
# 50%       4.309300     9.771000    10.143900     2.297400    42.040500
# 75%       8.400300    13.001475    13.826850     2.508500    49.039500
# max     644.074220   396.246310   367.274690     2.860700    61.845600
#
#                 dt       mudwgt
# count  8454.000000  8521.000000
# mean    100.568500     9.868196
# std      18.731108     0.387386
# min      54.897900     8.900000
# 25%      85.854425     9.500000
# 50%     101.909000     9.800000
# 75%     112.226600    10.200000
# max     161.839000    10.300000

# %%
# make a plot of logging
## gamma ray along with the depth
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5, 15))

# plt.plot(well_df["gr"], well_df["m__depth.ft"])
plt.scatter(well_df["gr"], well_df["m__depth.ft"], color="black", s=.5)

plt.title("GR")
plt.xlabel("gamma ray")
plt.ylabel("depth (ft)")
plt.show()
